# %%
import pandas as pd

# %%
df=pd.read_csv("world-happiness-report - world-happiness-report.csv")

# %%
df.head(5)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.tail(5)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1944                              54.4                         0.733
# 1945                              55.0                         0.753
# 1946                              55.6                         0.763
# 1947                              56.2                         0.632
# 1948                              56.8                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.sample(5)
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 409                 Costa Rica  2019        6.998               9.885
# 309   Central African Republic  2010        3.568               7.091
# 1024                Luxembourg  2017        7.061              11.634
# 1772              Turkmenistan  2014        5.787               9.427
# 1507                    Serbia  2019        6.241               9.808
#
#       Social support  Healthy life expectancy at birth  \
# 409            0.906                             71.50
# 309            0.483                             42.70
# 1024           0.905                             72.60
# 1772           0.909                             60.76
# 1507           0.903                             68.60
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 409                          0.927      -0.146                      0.836
# ...

# %%
df.shape
# Out:
# (1949, 11)

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df.dtypes
# Out:
# Country name                         object
# year                                  int64
# Life Ladder                         float64
# Log GDP per capita                  float64
# Social support                      float64
# Healthy life expectancy at birth    float64
# Freedom to make life choices        float64
# Generosity                          float64
# Perceptions of corruption           float64
# Positive affect                     float64
# Negative affect                     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %%
df[df["Log GDP per capita"].isnull()]
# Out:
#                    Country name  year  Life Ladder  Log GDP per capita  \
# 423                        Cuba  2006        5.418                 NaN
# 436                      Cyprus  2020        6.260                 NaN
# 709   Hong Kong S.A.R. of China  2020        5.295                 NaN
# 771                        Iran  2018        4.278                 NaN
# 772                        Iran  2019        5.006                 NaN
# 773                        Iran  2020        4.865                 NaN
# 918                      Kosovo  2020        6.294                 NaN
# 1087                      Malta  2020        6.157                 NaN
# 1280               North Cyprus  2012        5.463                 NaN
# 1281               North Cyprus  2013        5.567                 NaN
# 1282               North Cyprus  2014        5.786                 NaN
# 1283               North Cyprus  2015        5.843                 NaN
# ...

# %%
df[df["Country name"]=="Cuba"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 423         Cuba  2006        5.418                 NaN            0.97
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 423                             68.44                         0.281
#
#      Generosity  Perceptions of corruption  Positive affect  Negative affect
# 423         NaN                        NaN            0.647            0.277

# %%
df=df.dropna(subset="Log GDP per capita")

# %%
df=df.drop(columns=["Generosity","Perceptions of corruption"])

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                      13
# Healthy life expectancy at birth    37
# Freedom to make life choices        32
# Positive affect                     22
# Negative affect                     16
# dtype: int64

# %%
df[df["Social support"].isnull()]
# Out:
#               Country name  year  Life Ladder  Log GDP per capita  \
# 25                 Algeria  2010        5.464               9.287
# 112                Bahrain  2014        6.165              10.783
# 294                 Canada  2007        7.482              10.739
# 466               Djibouti  2010        5.006               7.812
# 925                 Kuwait  2014        6.180              10.945
# 1164               Morocco  2010        4.383               8.746
# 1310                  Oman  2011        6.853              10.382
# 1423                 Qatar  2010        6.850              11.520
# 1426                 Qatar  2015        6.375              11.486
# 1741               Tunisia  2009        5.025               9.197
# 1814  United Arab Emirates  2014        6.540              11.041
# 1837         United States  2007        7.513              10.933
# 1905               Vietnam  2017        5.175               8.876
#
# ...

# %%
df[df["Country name"]=="Algeria"]
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 26      Algeria  2011        5.317               9.297           0.810
# 27      Algeria  2012        5.605               9.311           0.839
# 28      Algeria  2014        6.355               9.335           0.818
# 29      Algeria  2016        5.341               9.362           0.749
# 30      Algeria  2017        5.249               9.354           0.807
# 31      Algeria  2018        5.043               9.348           0.799
# 32      Algeria  2019        4.745               9.337           0.803
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 26                             64.66                         0.530
# 27                             64.82                         0.587
# 28                             65.14                           NaN
# 29                             65.50                           NaN
# ...

# %%
df=df.dropna(subset=['Social support'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1900 entries, 0 to 1948
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1900 non-null   object
#  1   year                              1900 non-null   int64
#  2   Life Ladder                       1900 non-null   float64
#  3   Log GDP per capita                1900 non-null   float64
#  4   Social support                    1900 non-null   float64
#  5   Healthy life expectancy at birth  1863 non-null   float64
#  6   Freedom to make life choices      1874 non-null   float64
#  7   Positive affect                   1889 non-null   float64
#  8   Negative affect                   1894 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 148.4+ KB

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth    37
# Freedom to make life choices        26
# Positive affect                     11
# Negative affect                      6
# dtype: int64

# %%
df[df["Healthy life expectancy at birth"].isnull()]
# Out:
#                    Country name  year  Life Ladder  Log GDP per capita  \
# 699   Hong Kong S.A.R. of China  2006        5.511              10.746
# 700   Hong Kong S.A.R. of China  2008        5.137              10.816
# 701   Hong Kong S.A.R. of China  2009        5.397              10.788
# 702   Hong Kong S.A.R. of China  2010        5.643              10.847
# 703   Hong Kong S.A.R. of China  2011        5.474              10.887
# 704   Hong Kong S.A.R. of China  2012        5.484              10.893
# 705   Hong Kong S.A.R. of China  2014        5.458              10.940
# 706   Hong Kong S.A.R. of China  2016        5.498              10.970
# 707   Hong Kong S.A.R. of China  2017        5.362              11.000
# 708   Hong Kong S.A.R. of China  2019        5.659              11.000
# 905                      Kosovo  2007        5.104               8.928
# 906                      Kosovo  2008        5.522               8.981
# ...

# %%
df[df["Country name"]=="Hong Kong S.A.R. of China"]
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 699  Hong Kong S.A.R. of China  2006        5.511              10.746
# 700  Hong Kong S.A.R. of China  2008        5.137              10.816
# 701  Hong Kong S.A.R. of China  2009        5.397              10.788
# 702  Hong Kong S.A.R. of China  2010        5.643              10.847
# 703  Hong Kong S.A.R. of China  2011        5.474              10.887
# 704  Hong Kong S.A.R. of China  2012        5.484              10.893
# 705  Hong Kong S.A.R. of China  2014        5.458              10.940
# 706  Hong Kong S.A.R. of China  2016        5.498              10.970
# 707  Hong Kong S.A.R. of China  2017        5.362              11.000
# 708  Hong Kong S.A.R. of China  2019        5.659              11.000
#
#      Social support  Healthy life expectancy at birth  \
# 699           0.812                               NaN
# 700           0.840                               NaN
# ...

# %%
df=df[~((df['Country name']=="Hong Kong S.A.R. of China") & (df['Healthy life expectancy at birth'].isna()))]

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth    27
# Freedom to make life choices        26
# Positive affect                     11
# Negative affect                      6
# dtype: int64

# %%
df[df["Country name"]=="Kosovo"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 905       Kosovo  2007        5.104               8.928           0.848
# 906       Kosovo  2008        5.522               8.981           0.884
# 907       Kosovo  2009        5.891               9.008           0.830
# 908       Kosovo  2010        5.177               9.033           0.708
# 909       Kosovo  2011        4.860               9.067           0.759
# 910       Kosovo  2012        5.640               9.086           0.757
# 911       Kosovo  2013        6.126               9.113           0.721
# 912       Kosovo  2014        5.000               9.129           0.706
# 913       Kosovo  2015        5.077               9.182           0.805
# 914       Kosovo  2016        5.759               9.228           0.824
# 915       Kosovo  2017        6.149               9.262           0.792
# 916       Kosovo  2018        6.392               9.296           0.822
# ...

# %%
df=df[~((df['Country name']=="Kosovo") & (df['Healthy life expectancy at birth'].isna()))]

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth    14
# Freedom to make life choices        25
# Positive affect                     10
# Negative affect                      6
# dtype: int64

# %%
df[df["Negative affect"].isnull()]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 872        Jordan  2018        4.639               9.196           0.800
# 873        Jordan  2019        4.453               9.201           0.793
# 874        Jordan  2020        4.094               9.150           0.709
# 1062     Maldives  2018        5.198               9.826           0.913
# 1380  Philippines  2006        4.670               8.562           0.795
# 1753       Turkey  2005        4.719               9.809           0.820
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 872                               66.8                         0.762
# 873                               67.0                         0.726
# 874                               67.2                         0.779
# 1062                              70.6                         0.855
# 1380                              59.8                         0.828
# ...

# %%
df[df["Country name"]=="Jordan"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 860       Jordan  2005        6.295               9.246           0.920
# 861       Jordan  2007        5.598               9.321           0.841
# 862       Jordan  2008        4.930               9.343           0.766
# 863       Jordan  2009        6.000               9.347           0.899
# 864       Jordan  2010        5.570               9.317           0.918
# 865       Jordan  2011        5.539               9.289           0.878
# 866       Jordan  2012        5.132               9.261           0.829
# 867       Jordan  2013        5.172               9.237           0.840
# 868       Jordan  2014        5.333               9.222           0.816
# 869       Jordan  2015        5.405               9.207           0.830
# 870       Jordan  2016        5.271               9.197           0.820
# 871       Jordan  2017        4.808               9.194           0.815
# ...

# %%
df["Negative affect"].mean()
# Out:
# np.float64(0.2687525387493319)

# %%
df["Negative affect"]=df["Negative affect"].fillna(df["Negative affect"].mean())

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth    14
# Freedom to make life choices        25
# Positive affect                     10
# Negative affect                      0
# dtype: int64

# %%
df[df["Positive affect"].isnull()]
# Out:
#               Country name  year  Life Ladder  Log GDP per capita  \
# 126             Bangladesh  2014        4.636               8.164
# 135                Belarus  2008        5.463               9.677
# 264               Cambodia  2007        4.156               7.829
# 779                   Iraq  2013        4.725               9.280
# 872                 Jordan  2018        4.639               9.196
# 873                 Jordan  2019        4.453               9.201
# 874                 Jordan  2020        4.094               9.150
# 1062              Maldives  2018        5.198               9.826
# 1311              Pakistan  2005        5.225               8.218
# 1813  United Arab Emirates  2013        6.621              11.001
#
#       Social support  Healthy life expectancy at birth  \
# 126            0.577                             62.38
# 135            0.904                             61.70
# 264            0.675                             56.10
# ...

# %%
df[df["Country name"]=="Bangladesh"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 118   Bangladesh  2006        4.319               7.783           0.672
# 119   Bangladesh  2007        4.607               7.839           0.514
# 120   Bangladesh  2008        5.052               7.886           0.467
# 121   Bangladesh  2009        5.083               7.924           0.528
# 122   Bangladesh  2010        4.858               7.967           0.549
# 123   Bangladesh  2011        4.986               8.018           0.606
# 124   Bangladesh  2012        4.724               8.070           0.582
# 125   Bangladesh  2013        4.660               8.116           0.530
# 126   Bangladesh  2014        4.636               8.164           0.577
# 127   Bangladesh  2015        4.633               8.216           0.601
# 128   Bangladesh  2016        4.556               8.274           0.649
# 129   Bangladesh  2017        4.310               8.334           0.713
# ...

# %%
df=df.dropna(subset=["Positive affect"])

# %%
df[df["Positive affect"].isna()]
# Out:
# Empty DataFrame
# Columns: [Country name, year, Life Ladder, Log GDP per capita, Social support, Healthy life expectancy at birth, Freedom to make life choices, Positive affect, Negative affect]
# Index: []

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth    14
# Freedom to make life choices        24
# Positive affect                      0
# Negative affect                      0
# dtype: int64

# %%
df[df["Freedom to make life choices"].isnull()]
# Out:
#       Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 28         Algeria  2014        6.355               9.335           0.818
# 29         Algeria  2016        5.341               9.362           0.749
# 263       Cambodia  2006        3.569               7.746           0.793
# 342          China  2006        4.560               8.696           0.747
# 343          China  2007        4.863               8.824           0.811
# 350          China  2014        5.196               9.386           0.820
# 351          China  2015        5.304               9.449           0.794
# 352          China  2016        5.325               9.510           0.742
# 500          Egypt  2008        4.632               9.186           0.738
# 860         Jordan  2005        6.295               9.246           0.920
# 862         Jordan  2008        4.930               9.343           0.766
# 949           Laos  2012        4.876               8.611           0.693
# ...

# %%
df[df["Country name"]=="Algeria"]
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 26      Algeria  2011        5.317               9.297           0.810
# 27      Algeria  2012        5.605               9.311           0.839
# 28      Algeria  2014        6.355               9.335           0.818
# 29      Algeria  2016        5.341               9.362           0.749
# 30      Algeria  2017        5.249               9.354           0.807
# 31      Algeria  2018        5.043               9.348           0.799
# 32      Algeria  2019        4.745               9.337           0.803
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 26                             64.66                         0.530
# 27                             64.82                         0.587
# 28                             65.14                           NaN
# 29                             65.50                           NaN
# ...

# %%
df["Freedom to make life choices"]=df["Freedom to make life choices"].fillna(df["Freedom to make life choices"].mean())

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth    14
# Freedom to make life choices         0
# Positive affect                      0
# Negative affect                      0
# dtype: int64

# %%
df[df["Country name"]=="Taiwan Province of China"]
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 1669  Taiwan Province of China  2006        6.189              10.613
# 1670  Taiwan Province of China  2008        5.548              10.606
# 1671  Taiwan Province of China  2010        6.229              10.691
# 1672  Taiwan Province of China  2011        6.309              10.705
# 1673  Taiwan Province of China  2012        6.126              10.716
# 1674  Taiwan Province of China  2013        6.340              10.750
# 1675  Taiwan Province of China  2014        6.363              10.798
# 1676  Taiwan Province of China  2015        6.450              10.842
# 1677  Taiwan Province of China  2016        6.513              10.855
# 1678  Taiwan Province of China  2017        6.359              10.871
#
#       Social support  Healthy life expectancy at birth  \
# 1669           0.882                             68.68
# 1670           0.830                             69.14
# ...

# %%
df[df["Country name"]=="Taiwan Province of China"]["Healthy life expectancy at birth"].mean()
# Out:
# np.float64(69.14)

# %%
df.loc[(df["Country name"]=="Taiwan Province of China") & (df["Healthy life expectancy at birth"].isna()),"Healthy life expectancy at birth"]=(69.14)

# %%
df.isnull().sum()
# Out:
# Country name                        0
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    7
# Freedom to make life choices        0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
df[df["Country name"]=="Palestinian Territories"]
# Out:
#                  Country name  year  Life Ladder  Log GDP per capita  \
# 1325  Palestinian Territories  2006        4.716               8.213
# 1326  Palestinian Territories  2007        4.151               8.218
# 1327  Palestinian Territories  2008        4.386               8.276
# 1328  Palestinian Territories  2009        4.470               8.329
# 1329  Palestinian Territories  2010        4.703               8.383
# 1330  Palestinian Territories  2011        4.751               8.474
# 1331  Palestinian Territories  2012        4.647               8.531
# 1332  Palestinian Territories  2013        4.844               8.489
# 1333  Palestinian Territories  2014        4.722               8.457
# 1334  Palestinian Territories  2015        4.695               8.480
# 1335  Palestinian Territories  2016        4.907               8.498
# 1336  Palestinian Territories  2017        4.628               8.485
#
#       Social support  Healthy life expectancy at birth  \
# ...

# %%
df[df["Country name"]=="Palestinian Territories"]["Healthy life expectancy at birth"].mean()
# Out:
# np.float64(62.014799999999994)

# %%
df.loc[(df["Country name"]=="Palestinian Territories") & (df["Healthy life expectancy at birth"].isna()),"Healthy life expectancy at birth"]=(62.014799999999994)

# %%
df.isnull().sum()
# Out:
# Country name                        0
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
df.to_csv("cleaned_data.csv")
